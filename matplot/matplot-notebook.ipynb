# %%
# %matplotlib notebook

# nbagg backend, which enables interactivity.

import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10)

# %%
line, = plt.plot(x, np.sin(x), '--', linewidth=2)
# Out:
# <img src="data:image/png;base64,..." width="484.99998948790835">

# %%
# %load http://matplotlib.sourceforge.net/mpl_examples/pylab_examples/integral_demo.py
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-5-1fb9a4edb680> in <module>()
# ----> 1 get_ipython().magic('load http://matplotlib.sourceforge.net/mpl_examples/pylab_examples/integral_demo.py')
#
# /opt/conda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2144         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2145         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2146         return self.run_line_magic(magic_name, magic_arg_s)
#    2147
#    2148     #-------------------------------------------------------------------------
#
# /opt/conda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2065                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2066             with self.builtin_trap:
# ...
